# %% [markdown]
# # Homework #5
#
# Objective of this HW.
#
# 1. Run an OLS regression using a different set of data. Use the regression class created in this chapter. Print the results.
#
# 2. Create scatter plots of the observation and predicted values as demonstrated at the end of this chapter.
#
# 3. Use the numpy libraries log function to log some or all value in your data. Print the columns of data that have been logged. (hint: pass the appropriate list of keys to the dataframe, data[[key1,key2,key3…]])
#
# 4. Run the same regression again. Print the results. How has the significance changed?
#
# 5. Plot the new results using scatter plots as in question 2.
#
# 6. Create 2 unique visualizations of the results using matplotlib (e.g., time series predicted values and observations, plots with more than 2 variables represented such as 3D plane or changing size of dots, a plot comparing results of the logged and unlogged regression, etc…). For visualization ideas visit the matplotlib website.
#
#
# Running an OLS regression to predict CPI. CPI is an extremely important indicator that tracks inflation. Inflation touches everyone. It determines how much comsumers pay for good and services. The independent variables I used were,
#
# > CPIAUCSL: Consumer Price Index for All Urban Consumers: All Items in U.S. City Average, (Index 1982-1984=100), Seasonally Adjusted
#
# > DGORDER: Manufacturers' New Orders: Durable Goods, (Millions of Dollars), Seasonally Adjusted
#
# > PERMIT: New Private Housing Units Authorized by Building Permits, (Thousands of Units), Seasonally Adjusted Annual Rate
#
# > RSAFS: Advance Retail Sales: Retail and Food Services, Total, (Millions of Dollars), Seasonally Adjusted
#
# > M2: M2 Money Stock, (Billions of Dollars), Seasonally Adjusted
#
# > M2V: Velocity of M2 Money Stock, (Ratio), Seasonally Adjusted

# %% [markdown]
# #### 1. Running my OLS

# %%
import pandas as pd

data = pd.read_csv("CPI_OLS.csv", index_col = "DATE")
data
# Out:
#              CPIAUCSL      DGORDER       PERMIT        RSAFS            M2  \
# DATE
# 7/1/2010   217.934333  193819.3333   574.000000  356875.0000   8645.953846
# 10/1/2010  219.699000  194712.3333   583.333333  366705.3333   8758.461538
# 1/1/2011   222.043667  203767.6667   567.000000  375108.3333   8865.000000
# 4/1/2011   224.568333  203173.0000   611.666667  381417.3333   9030.523077
# 7/1/2011   226.032667  210242.0000   626.000000  384815.0000   9438.915385
# 10/1/2011  227.047333  216838.6667   691.333333  391115.6667   9603.676923
# 1/1/2012   228.326000  223690.6667   752.000000  399136.0000   9766.438462
# 4/1/2012   228.808000  218707.3333   774.000000  398472.6667   9907.638462
# 7/1/2012   229.841000  214439.6667   873.000000  401658.6667  10106.307690
# 10/1/2012  231.369333  221964.3333   915.000000  407432.6667  10336.621430
# 1/1/2013   232.299333  219196.6667   952.000000  414568.3333  10486.483330
# 4/1/2013   232.045000  231089.6667   985.666667  414015.6667  10610.076920
# 7/1/2013   233.300000  222999.3333   988.333333  417808.6667  10773.514290
# 10/1/2013  234.162667  230947.0000  1026.000000  420906.0000  10970.600000
# 1/1/2014   235.621000  228307.3333  1027.333333  424110.6667  11133.323080
# 4/1/2014   236.872333  234942.0000  1039.333333  434476.3333  11309.538460
# 7/1/2014   237.478333  254902.6667  1066.666667  438164.6667  11458.176920
# 10/1/2014  236.888333  227138.3333  1074.333333  439988.6667  11601.007690
# 10/1/2019  257.832333  239548.6667  1490.000000  525111.3333  15235.200000
# 1/1/2020   258.607667  230877.3333  1443.333333  513612.6667  15600.430770
# 4/1/2020   256.294667  189193.6667  1180.000000  476982.0000  17667.630770
#
#              M2V  Constant  CPIAUCSL estimator
# DATE
# 7/1/2010   1.743         1          219.093579
# 10/1/2010  1.740         1          220.577629
# 1/1/2011   1.723         1          222.798159
# 4/1/2011   1.714         1          223.624564
# 7/1/2011   1.650         1          225.747992
# 10/1/2011  1.643         1          227.061369
# 1/1/2012   1.639         1          228.630744
# 4/1/2012   1.629         1          228.373082
# 7/1/2012   1.606         1          228.145289
# 10/1/2012  1.582         1          229.852587
# 1/1/2013   1.579         1          230.599459
# 4/1/2013   1.567         1          231.730333
# 7/1/2013   1.563         1          231.940220
# 10/1/2013  1.557         1          233.353359
# 1/1/2014   1.536         1          233.958582
# 4/1/2014   1.541         1          236.238537
# 7/1/2014   1.546         1          238.760578
# 10/1/2014  1.538         1          236.837712
# 1/1/2015   1.523         1          236.948731
# 4/1/2015   1.525         1          236.741979
# 7/1/2015   1.516         1          238.752189
# 10/1/2015  1.499         1          238.609702
# 1/1/2016   1.474         1          239.493464
# 4/1/2016   1.463         1          240.459983
# 7/1/2016   1.452         1          241.248244
# 10/1/2016  1.447         1          242.714078
# 1/1/2017   1.442         1          244.046984
# 4/1/2017   1.433         1          245.696535
# 7/1/2017   1.435         1          246.420501
# 10/1/2017  1.445         1          248.492774
# 1/1/2018   1.456         1          249.203307
# 4/1/2018   1.462         1          251.147993
# 7/1/2018   1.461         1          252.768291
# 10/1/2018  1.465         1          252.846561
# 1/1/2019   1.459         1          253.832961
# 4/1/2019   1.454         1          254.568927
# 7/1/2019   1.442         1          255.686498
# 10/1/2019  1.427         1          256.123619
# 1/1/2020   1.381         1          255.535125
# 4/1/2020   1.104         1          256.034448

# %%
reg.y_hat
# Out:
# matrix([[219.09357942],
#         [220.57762915],
#         [222.79815857],
#         [223.62456371],
#         [225.747992  ],
#         [227.06136914],
#         [228.63074419],
#         [228.37308239],
#         [228.14528873],
#         [229.85258654],
#         [230.59945888],
#         [231.73033278],
#         [231.94021974],
#         [233.35335894],
#         [233.95858214],
#         [236.2385374 ],
#         [238.760578  ],
#         [236.83771196],
#         [236.94873072],
#         [236.74197887],
#         [238.75218905],
#         [238.60970171],
#         [239.49346445],
#         [240.45998266],
#         [241.24824423],
#         [242.71407768],
#         [244.0469839 ],
#         [245.69653539],
#         [246.42050113],
#         [248.49277426],
#         [249.20330701],
#         [251.14799294],
#         [252.76829067],
#         [252.84656064],
#         [253.83296123],
#         [254.56892652],
#         [255.68649751],
#         [256.12361905],
#         [255.53512533],
#         [256.0344479 ]])

# %%
reg.betas
# Out:
# matrix([[ 9.10070937e-05],
#         [-8.17912419e-03],
#         [ 1.12670613e-04],
#         [ 3.36958298e-03],
#         [ 2.52493282e+00],
#         [ 1.32405921e+02]])

# %%
reg.ssr, reg.sse, reg.sst
# Out:
# (4693.876726138488, 48.164339213347894, 4742.041065298936)

# %% [markdown]
# Next, we will use the sum squared statistics (ssr, sse, and sst) to calculate different variables that reflect goodness of fit of the regression and its parts.

# %%
# Creating this chart into a csv file
reg.cov_matrix.to_csv("regCovMatrix.csv")
reg.cov_matrix
# Out:
#                DGORDER        PERMIT         RSAFS            M2         M2V  \
# DGORDER   7.581475e-10  1.578220e-08 -8.178404e-10  1.795590e-08    0.000109
# PERMIT    1.578220e-08  1.105439e-05 -1.086684e-07  2.047803e-06    0.021846
# RSAFS    -8.178404e-10 -1.086684e-07  1.942465e-09 -4.322682e-08   -0.000362
# M2        1.795590e-08  2.047803e-06 -4.322682e-08  1.083247e-06    0.009495
# M2V       1.090440e-04  2.184588e-02 -3.623536e-04  9.495387e-03   96.584132
# Constant -2.066291e-04 -2.509205e-02  5.105947e-04 -1.455749e-02 -148.631515
#
#             Constant
# DGORDER    -0.000207
# PERMIT     -0.025092
# RSAFS       0.000511
# M2         -0.014557
# M2V      -148.631515
# Constant  248.616693

# %% [markdown]
# Next, we have included the code for generating standerd error, t-stats, and p-value.

# %%
reg.estimates
# Out:
#               Coefficient         SE    t-stat  p-value signficance
# y = CPIAUCSL
# DGORDER          0.000091   0.000028  3.305205  0.00216          **
# PERMIT          -0.008179   0.003325 -2.460024  0.01883           *
# RSAFS            0.000113   0.000044  2.556431  0.01494           *
# M2               0.003370   0.001041  3.237520  0.00259          **
# M2V              2.524933   9.827723  0.256919  0.79870
# Constant       132.405921  15.767584  8.397350  0.00000         ***

# %%
reg = Regression()
reg.OLS("CPI_OLS", data, y_var, x_vars)
# Out:
# You created an instance of stats()

# %%
# Creating the chart below into a CSV. 
reg.stats_DF.to_csv("reg_stats.csv")
reg.stats_DF
# Out:
#          Estimation Statistics
# r**2                  0.989843
# f-stat              682.188059
# Est Var               1.376124
# rootMSE               1.173083
# SSE                  48.164339
# SSR                4693.876726
# SST                4742.041065
# Obs.                 41.000000
# DOF                  35.000000

# %%
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages

def plot_scatter_with_estimator(title, data, x_vars, y_var, pp = None):
    # set default font size
    plt.rcParams.update({"font.size":19})
    # use a loop to call each exogenous
    y = y_var[0]
    for x in x_vars:
        fig, ax = plt.subplots(figsize=(12,8))
        y_label1 = "Estimate"
        y_label2 = "Observation"
        data.plot.scatter(x=x, y=y + " estimator", ax = ax, c = "r",
                         s = 10, label = y_label1, legend = False)
        
        # erase the y_axis label so that "estimtor" is not present
        plt.ylabel("")
        data.plot.scatter(x = x, y = y, ax = ax, s = 10, 
                          label = y_label2, legend = False)
        plt.legend(loc="upper left", labels = [y_label1, y_label2],
                  bbox_to_anchor = (0, 1.17))
        
        plt.title("Observations and\nOLS Estimates")
        # remove lines marking unit on the axis
        ax.xaxis.set_ticks_position("none")
        ax.yaxis.set_ticks_position("none")
        pp.savefig(fig, bbox_inches = "tight")
pp = PdfPages("RegressionPlots.pdf")
plot_scatter_with_estimator("Plot", reg.data, x_vars, y_var, pp)

### plot 

pp.close()

# %%
import numpy as np
import pandas as pd

data2 = pd.read_csv("CPI_OLS.csv", index_col = "DATE")

data2['log DGORDER'] = np.log(data2['DGORDER']) 
data2['log PERMIT'] = np.log(data2['PERMIT']) 
data2['log RSAFS'] = np.log(data2['RSAFS'])

# %%
skip_keys = ["DGORDER", "PERMIT", "RSAFS"]
data2 = data2.drop(skip_keys, axis = 1)

# %%
data2.keys()
# Out:
# Index(['CPIAUCSL', 'M2', 'M2V', 'log DGORDER', 'log PERMIT', 'log RSAFS'], dtype='object')

# %%
data2
# Out:
#              CPIAUCSL            M2    M2V  log DGORDER  log PERMIT  log RSAFS
# DATE
# 7/1/2010   217.934333   8645.953846  1.743    12.174682    6.352629  12.785141
# 10/1/2010  219.699000   8758.461538  1.740    12.179279    6.368759  12.812314
# 1/1/2011   222.043667   8865.000000  1.723    12.224736    6.340359  12.834970
# 4/1/2011   224.568333   9030.523077  1.714    12.221813    6.416187  12.851649
# 7/1/2011   226.032667   9438.915385  1.650    12.256015    6.439350  12.860518
# 10/1/2011  227.047333   9603.676923  1.643    12.286909    6.538622  12.876759
# 1/1/2012   228.326000   9766.438462  1.639    12.318019    6.622736  12.897057
# 4/1/2012   228.808000   9907.638462  1.629    12.295490    6.651572  12.895394
# 7/1/2012   229.841000  10106.307690  1.606    12.275784    6.771936  12.903358
# 10/1/2012  231.369333  10336.621430  1.582    12.310272    6.818924  12.917631
# 1/1/2013   232.299333  10486.483330  1.579    12.297725    6.858565  12.934993
# 4/1/2013   232.045000  10610.076920  1.567    12.350561    6.893318  12.933659
# 7/1/2013   233.300000  10773.514290  1.563    12.314924    6.896020  12.942779
# 10/1/2013  234.162667  10970.600000  1.557    12.349944    6.933423  12.950165
# 1/1/2014   235.621000  11133.323080  1.536    12.338448    6.934722  12.957750
# 4/1/2014   236.872333  11309.538460  1.541    12.367094    6.946335  12.981897
# 7/1/2014   237.478333  11458.176920  1.546    12.448637    6.972294  12.990350
# 10/1/2014  236.888333  11601.007690  1.538    12.333315    6.979456  12.994504
# 1/1/2015   235.355000  11812.753850  1.523    12.321950    6.988721  12.989464
# 4/1/2015   236.960000  11951.938460  1.525    12.322361    7.147821  13.006357
# 7/1/2015   237.855000  12096.807690  1.516    12.325503    7.046647  13.015877
# 10/1/2015  237.837000  12257.815380  1.499    12.317499    7.093405  13.015310
# 1/1/2016   237.777000  12520.046150  1.474    12.293638    7.053874  13.018492
# 4/1/2016   239.473000  12749.115380  1.463    12.288520    7.078060  13.029374
# 7/1/2016   240.591333  12952.600000  1.452    12.287696    7.111512  13.038615
# 10/1/2016  242.115333  13147.615380  1.447    12.311858    7.133030  13.049298
# 1/1/2017   243.822000  13332.092310  1.442    12.311341    7.155656  13.067630
# 4/1/2017   244.054333  13515.853850  1.433    12.349336    7.141509  13.069929
# 7/1/2017   245.359000  13659.869230  1.435    12.341831    7.152269  13.079285
# matrix([[219.09357942],
#         [220.57762915],
#         [222.79815857],
#         [223.62456371],
#         [225.747992  ],
#         [227.06136914],
#         [228.63074419],
#         [228.37308239],
#         [228.14528873],
#         [229.85258654],
#         [230.59945888],
#         [231.73033278],
#         [231.94021974],
#         [233.35335894],
#         [233.95858214],
#         [236.2385374 ],
#         [238.760578  ],
#         [236.83771196],
#         [236.94873072],
#         [236.74197887],
#         [238.75218905],
#         [238.60970171],
#         [239.49346445],
#         [240.45998266],
#         [241.24824423],
#         [242.71407768],
#         [244.0469839 ],
#         [245.69653539],
#         [246.42050113],
#         [248.49277426],
#         [249.20330701],
#         [251.14799294],
#         [252.76829067],
#         [252.84656064],
#         [253.83296123],
#         [254.56892652],
#         [255.68649751],
#         [256.12361905],
#         [255.53512533],
#         [256.0344479 ]])

# %%
reg2.betas
# Out:
# matrix([[ 9.10070937e-05],
#         [-8.17912419e-03],
#         [ 1.12670613e-04],
#         [ 3.36958298e-03],
#         [ 2.52493282e+00],
#         [ 1.32405921e+02]])

# %%
reg2.ssr, reg2.sse, reg2.sst
# Out:
# (4693.876726138488, 48.164339213347894, 4742.041065298936)

# %% [markdown]
# Next, we will use the sum squared statistics (ssr, sse, and sst) to calculate different variables that reflect goodness of fit of the regression and its parts.

# %%
# Creating this chart into a csv file
reg2.cov_matrix.to_csv("reg2CovMatrix.csv")
reg2.cov_matrix
# Out:
#                DGORDER        PERMIT         RSAFS            M2         M2V  \
# DGORDER   7.581475e-10  1.578220e-08 -8.178404e-10  1.795590e-08    0.000109
# PERMIT    1.578220e-08  1.105439e-05 -1.086684e-07  2.047803e-06    0.021846
# RSAFS    -8.178404e-10 -1.086684e-07  1.942465e-09 -4.322682e-08   -0.000362
# M2        1.795590e-08  2.047803e-06 -4.322682e-08  1.083247e-06    0.009495
# M2V       1.090440e-04  2.184588e-02 -3.623536e-04  9.495387e-03   96.584132
# Constant -2.066291e-04 -2.509205e-02  5.105947e-04 -1.455749e-02 -148.631515
#
#             Constant
# DGORDER    -0.000207
# PERMIT     -0.025092
# RSAFS       0.000511
# M2         -0.014557
# M2V      -148.631515
# Constant  248.616693

# %% [markdown]
# Next, we have included the code for generating standerd error, t-stats, and p-value.

# %%
reg2.estimates
# Out:
#               Coefficient         SE    t-stat  p-value signficance
# y = CPIAUCSL
# DGORDER          0.000091   0.000028  3.305205  0.00216          **
# PERMIT          -0.008179   0.003325 -2.460024  0.01883           *
# RSAFS            0.000113   0.000044  2.556431  0.01494           *
# M2               0.003370   0.001041  3.237520  0.00259          **
# M2V              2.524933   9.827723  0.256919  0.79870
# Constant       132.405921  15.767584  8.397350  0.00000         ***

# %%
reg2 = Regression()
reg2.OLS("CPI_OLS", data, y_var, x_vars)
# Out:
# You created an instance of stats()

# %%
# Creating the chart below into a CSV. 
reg2.stats_DF.to_csv("reg2_stats.csv")
reg2.stats_DF
# Out:
#          Estimation Statistics
# r**2                  0.989843
# f-stat              682.188059
# Est Var               1.376124
# rootMSE               1.173083
# SSE                  48.164339
# SSR                4693.876726
# SST                4742.041065
# Obs.                 41.000000
# DOF                  35.000000

# %% [markdown]
# In both regression there was a few statistically significant independent variables and the 2nd regression did not improve the goodness-of-fit (r**2) or the f-statistic. In both regressions stayed almost exactly the same, meaning there was must not have been to much skewness in the data. It appears that log DGORDER, PERMIT, and RSAFS does not imporve the regression.

# %%
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages

def plot_scatter_with_estimator(title, data, x_vars, y_var, pp = None):
    # set default font size
    plt.rcParams.update({"font.size":19})
    # use a loop to call each exogenous
    y = y_var[0]
    for x in x_vars:
        fig, ax = plt.subplots(figsize=(12,8))
        y_label1 = "Estimate"
        y_label2 = "Observation"
        data.plot.scatter(x=x, y=y + " estimator", ax = ax, c = "r",
                         s = 10, label = y_label1, legend = False)
        
        # erase the y_axis label so that "estimtor" is not present
        plt.ylabel("")
        data.plot.scatter(x = x, y = y, ax = ax, s = 10, 
                          label = y_label2, legend = False)
        plt.legend(loc="upper left", labels = [y_label1, y_label2],
                  bbox_to_anchor = (0, 1.17))
        
        plt.title("Observations and\nOLS Estimates")
        # remove lines marking unit on the axis
        ax.xaxis.set_ticks_position("none")
        ax.yaxis.set_ticks_position("none")
        pp.savefig(fig, bbox_inches = "tight")
pp = PdfPages("RegressionPlots.pdf")
plot_scatter_with_estimator("Plot", reg2.data, x_vars, y_var, pp)

### plot 

pp.close()

# %% [markdown]
# #### Q6. Two new visualizations using matplot lab.

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

plt.rcParams.update({'font.size': 32})
# create a new figure to use for plotting
fig, ax = plt.subplots(figsize = (24,16))
data.plot.line(ax = ax, legend = True)

plt.rcParams.update({'font.size': 32})
# create a new figure to use for plotting
fig, ax = plt.subplots(figsize = (24,16))
data2.plot.line(ax = ax, legend = True)

# %%
import numpy as np
import pandas as pd

data3 = pd.read_csv("CPI_OLS.csv", index_col = "DATE")

data3['log DGORDER'] = np.log(data3['DGORDER']) 
data3['log PERMIT'] = np.log(data3['PERMIT']) 
data3['log RSAFS'] = np.log(data3['RSAFS']) 

skip_keys2 = ["CPIAUCSL", "DGORDER", "PERMIT", "RSAFS", "M2", "M2V"]
data3 = data3.drop(skip_keys2, axis = 1)

data4 = pd.read_csv("CPI_OLS.csv", index_col = "DATE")

skip_keys3 = ["CPIAUCSL", "M2", "M2V"]
data4 = data4.drop(skip_keys3, axis = 1)

# %%
data3.keys()
# Out:
# Index(['log DGORDER', 'log PERMIT', 'log RSAFS'], dtype='object')

# %%
data4.keys()
# Out:
# Index(['DGORDER', 'PERMIT', 'RSAFS'], dtype='object')

# %% [markdown]
# Charts that show the logged vs nonlogged datasets.

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

# non logged data 
plt.rcParams.update({'font.size': 32})
# create a new figure to use for plotting
fig, ax = plt.subplots(figsize = (24,16))
data4.plot.line(ax = ax, legend = True)

# logged data 
plt.rcParams.update({'font.size': 32})
# create a new figure to use for plotting
fig, ax = plt.subplots(figsize = (24,16))
data3.plot.line(ax = ax, legend = True)
