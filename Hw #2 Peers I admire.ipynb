# %% [markdown]
# # HW 2
#
# > Create a dictionary with the same structure as the dictionary we created in the in class project for 10 professionals or specialists that you admire. The dictionary should include keys that identify the name of the professional, their area of expertise, a short biography, and a link to their website.
#
# > Print the dataframe and save this dataframe as a csv.

# %%
import pandas as pd
Professional_dict = {"Ravi Zacheries":{"Areas of Specialization":"Apologist",
                                     "Bio":"Ravi Zacharias was an Indian-born Canadian-American Christian apologist. Zacharias was the author of more than 30 books on Christianity. Zacharias was the founder and chairman of the board of Ravi Zacharias International Ministries (RZIM).",
                                      "Website":"https://www.rzim.org"},
                 "Tim Tebow":{"Areas of Specialization": "Professional Athlete, Christian",
                                    "Bio":"Tim is a American professional baseball player for the New York Mets organization, former professional football quarterback, and broadcaster. Founder of the Tim Tebow Foundation.",
                                     "Website":"https://www.timtebowfoundation.org/"},
                 "Warren Buffett":{"Areas of Specialization": "Investing, Finance",
                                 "Bio":"Warren Edward Buffett is an American investor, business tycoon, and philanthropist, who is the chairman and CEO of Berkshire Hathaway.",
                                 "Website":"https://en.wikipedia.org/wiki/Warren_Buffett"},
                 "Peter Lynch":{"Areas of Specialization": "Investing, Finance",
                                 "Bio":"Peter is an American investor, mutual fund manager, and philanthropist. As the manager of the Magellan Fund[2] at Fidelity Investments between 1977 and 1990, Lynch averaged a 29.2% annual return,[3] consistently more than doubling the S&P 500 stock market index and making it the best-performing mutual fund in the world.",
                                 "Website":"https://en.wikipedia.org/wiki/Peter_Lynch"},
                 "Erik Barner":{"Areas of Specialization": "Private Equity, Finance",
                                 "Bio":"Erik Barner is the Chief Investment Officer of Gen7 Investments, bringing over a decade of experience in the financial industry.",
                                 "website":"https://gen7investments.com/about/"},
                 "Howard Marks":{"Areas of Specialization": "Investing, FInance",
                                 "Bio":"Howard is an American investor and writer. He is the co-founder and co-chairman of Oaktree Capital Management, the largest investor in distressed securities worldwide.",
                                "Website":"https://en.wikipedia.org/wiki/Howard_Marks_(investor)"},
                 "Bill Gates":{"Areas of Specialization": "Computer Programming, Software Engineer",
                                 "Bio":" is an American business magnate, software developer, investor, and philanthropist. He is best known as the co-founder of Microsoft Corporation. Co-Founder of the Bill and Melinda Gates Foundation.",
                                "Website":"https://www.gatesfoundation.org/"},
                 "Dwayne Johnson":{"Areas of Specialization": "Acting, Entertainment",
                                 "Bio":"The Rock, is an American-Canadian actor, producer, businessman, retired professional wrestler, and former American football player.",
                                "Website":"https://en.wikipedia.org/wiki/Dwayne_Johnson"},
                 "Frayne Olson":{"Areas of Specialization": "Crop Economist, Marketing Specialist",
                                 "Bio":"Frayne Olson teaches crop marketing strategies, crop outlook and price analysis, and the economics of crop contracting.",
                                 "Website":"https://www.ndsu.edu/agecon/faculty/olson/#c625016"},
                 "William Wilson":{"Areas of Specialization": "Grain marketing, transportation, and logistics",
                                 "Bio":"Bill Wilson teaches grain marketing, transportation, international trade, and marketing and logistics.",
                                "Website":"https://www.ndsu.edu/agecon/faculty/wilson/#c629178"},
                }
Professional_dict
# Out:
# {'Ravi Zacheries': {'Areas of Specialization': 'Apologist',
#   'Bio': 'Ravi Zacharias was an Indian-born Canadian-American Christian apologist. Zacharias was the author of more than 30 books on Christianity. Zacharias was the founder and chairman of the board of Ravi Zacharias International Ministries (RZIM).',
#   'Website': 'https://www.rzim.org'},
#  'Tim Tebow': {'Areas of Specialization': 'Professional Athlete, Christian',
#   'Bio': 'Tim is a American professional baseball player for the New York Mets organization, former professional football quarterback, and broadcaster. Founder of the Tim Tebow Foundation.',
#   'Website': 'https://www.timtebowfoundation.org/'},
#  'Warren Buffett': {'Areas of Specialization': 'Investing, Finance',
#   'Bio': 'Warren Edward Buffett is an American investor, business tycoon, and philanthropist, who is the chairman and CEO of Berkshire Hathaway.',
#   'Website': 'https://en.wikipedia.org/wiki/Warren_Buffett'},
# ...

# %%
Professional_df = pd.DataFrame(Professional_dict)
Professional_df.to_csv("NDSUAAEProfessionalInfo.csv")
Professional_df
# Out:
#                                                             Ravi Zacheries  \
# Areas of Specialization                                          Apologist
# Bio                      Ravi Zacharias was an Indian-born Canadian-Ame...
# Website                                               https://www.rzim.org
# website                                                                NaN
#
#                                                                  Tim Tebow  \
# Areas of Specialization                    Professional Athlete, Christian
# Bio                      Tim is a American professional baseball player...
# Website                                https://www.timtebowfoundation.org/
# website                                                                NaN
#
#                                                             Warren Buffett  \
# Areas of Specialization                                 Investing, Finance
# ...
